# %%
import pandas as pd
import matplotlib.pyplot as plt
#required libraries to get an overview of dataset with Python

# %%
def extract(filename):
    #filename = input("Please indicate what datafile you would like to plot:") #indicate file (obsolete if we are calling this as a function)
    file = "/files/Macroeconometrics/Temperature/dat/" + filename  # identify location
    text = open(file, 'r')  #open text file
    
    table=[]  #create an empty table where relevant data will be inserted
    for line in text:
        column = line.split()   #split text file into words using the in-built split function
        if line[0] == '#':   #ignore comments
            continue
        elif len(column) == 0: #ignore empty lines
            continue
        else:
            year = int(column[0])  #define year variable
            temp_jan = column[1]  #define year variable
            temp_feb = column[2]
            temp_mar = column[3]
            temp_apr = column[4]
            temp_may = column[5]
            temp_jun = column[6]
            temp_jul = column[7]
            temp_aug = column[8]
            temp_sep = column[9]
            temp_oct = column[10]
            temp_nov = column[11]
            temp_dec= column[12]
            table.append([year, temp_jan, temp_feb, temp_mar, temp_apr, temp_may, temp_jun, temp_jul, temp_aug, temp_sep, temp_oct, temp_nov, temp_dec])  #insert variables
    text.close()
    return(table)

# %%
x = extract("temp_data.txt")
#x

# %%
#products_list = [['laptop', 1300], ['printer', 150], ['tablet', 300], ['desk', 450], ['chair', 200]]

data = pd.DataFrame(x, columns=['Year', 'January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'])
data
# Out:
#      Year January February  March April    May   June   July August September  \
# 0    1864    -7.1    -4.52   0.04   2.1   7.43   9.48  12.37  10.95      8.59
# 1    1865   -3.46    -6.26  -5.91  7.01   10.1  10.98  13.98  11.16     11.89
# 2    1866   -1.31    -0.42     -1   4.1   4.96  12.02  12.25   9.99      9.69
# 3    1867   -3.87     0.55  -0.13  3.48   7.74  10.57  11.29  12.94     10.42
# 4    1868   -5.46    -1.54   -2.3  2.32  12.04  11.96  12.88   12.5     11.12
# ..    ...     ...      ...    ...   ...    ...    ...    ...    ...       ...
# 155  2019   -4.38     0.74   2.29  4.49   6.11  15.26  16.21  15.11     11.39
# 156  2020   -0.29     1.63   1.56  7.63   9.56  11.83   15.4  15.21     11.89
# 157  2021   -3.57     0.83   0.94  2.88   6.24  14.37   13.9  13.11     12.14
# 158  2022   -1.49    -0.14   2.37  4.62  11.49  15.36  16.96  16.13     10.08
# 159  2023   -1.62     0.07   2.65   3.7   9.34  14.93  15.97  15.57     14.29
#
#     October November December
# 0      3.51    -0.51    -4.47
# 1      5.21     1.26    -3.07
# 2      5.35     -0.2    -0.49
# 3      2.93    -1.43     -5.8
# 4      4.78    -1.99     1.27
# ..      ...      ...      ...
# 155    8.45      1.5     0.75
# 156    5.36     3.68    -1.21
# 157    6.27     1.12    -0.66
# 158   10.44     3.32    -0.29
# 159     9.7     1.58     0.64
#
# [160 rows x 13 columns]

# %%
df = data.drop(range(111), axis='index')

# %%
df
# Out:
#      Year January February  March April    May   June   July August September  \
# 111  1975   -0.09    -1.61  -1.29  2.71   7.42   9.41  13.11  12.99     11.56
# 112  1976    -2.7    -1.26  -0.77  3.05   8.54  13.14   13.8  11.12      7.99
